# %%
# %pylab inline
import cv2
import matplotlib.pyplot as plt
import model
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
*images, s = model.load_driving_log('data/driving_log.csv', slice(10, 11))

# %%
images, steering = model.make_training_batch(*images, s)

# %%
for i in range(images.shape[0]):
    plt.figure()
    plt.imshow(images[i, :, :, 0])
    plt.title(steering[i])

# %%
import pickle

with open('data_cache/training-0.p', 'rb') as file:
    images, steering = pickle.load(file)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-7296d3429d36> in <module>()
#       1 import pickle
#       2
# ----> 3 with open('data_cache/training-0.p', 'rb') as file:
#       4     images, steering = pickle.load(file)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data_cache/training-0.p'

# %%
for i in range(0, 20):
    plt.figure()
    plt.imshow(images[i, :, :, 0], cmap='gray')
    plt.title(steering[i])
